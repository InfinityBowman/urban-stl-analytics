# %%
import pandas as pd
import json

with open("../../public/data/crime.json", "r") as f:
    crime = json.load(f)
with open("../../public/data/vacancies.json", "r") as f:
    vacancies = json.load(f)

# Extract crime neighborhoods and totals
crime_df = pd.DataFrame(crime["neighborhoods"]).T
crime_df = crime_df.rename(columns={"total": "crime_total"})

# Vacancies with coordinates
vacancies_df = pd.DataFrame(vacancies)

print(crime_df.head())
# Out:
#                  name crime_total  \
# 59      JeffVanderLou         133
# 38   Central West End         190
# 62    Columbus Square          48
# 15  Tower Grove South         127
# 09    Lindenwood Park          76
#
#                                           topOffenses felonies  \
# 59  {'BURGLARY - 2ND DEGREE': 10, 'LEAVING THE SCE...        0
# 38  {'STEALING': 15, 'STEALING - MOTOR VEHICLE/WAT...        0
# 62  {'ASSAULT 1ST DEGREE OR ATTEMPT': 5, 'ARMED CR...        0
# 15  {'STEALING - MOTOR VEHICLE/WATERCRAFT/AIRCRAFT...        0
# 09  {'BURGLARY - 2ND DEGREE': 11, 'STEALING - MOTO...        0
#
#    firearmIncidents
# 59               20
# 38               21
# 62               23
# 15               19
# 09                4
